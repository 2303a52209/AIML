# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a52209/AIML/blob/main/lab_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("/content/realtor-data.zip.csv")
df.head()
# Out:
#    brokered_by    status     price  bed  bath  acre_lot     street  \
# 0     103378.0  for_sale  105000.0  3.0   2.0      0.12  1962661.0
# 1      52707.0  for_sale   80000.0  4.0   2.0      0.08  1902874.0
# 2     103379.0  for_sale   67000.0  2.0   1.0      0.15  1404990.0
# 3      31239.0  for_sale  145000.0  4.0   2.0      0.10  1947675.0
# 4      34632.0  for_sale   65000.0  6.0   2.0      0.05   331151.0
#
#          city        state  zip_code  house_size prev_sold_date
# 0    Adjuntas  Puerto Rico     601.0       920.0            NaN
# 1    Adjuntas  Puerto Rico     601.0      1527.0            NaN
# 2  Juana Diaz  Puerto Rico     795.0       748.0            NaN
# 3       Ponce  Puerto Rico     731.0      1800.0            NaN
# 4    Mayaguez  Puerto Rico     680.0         NaN            NaN

# %% [markdown]
# #CHECK BASIC INFO ON DATA SET

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2226382 entries, 0 to 2226381
# Data columns (total 12 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   brokered_by     float64
#  1   status          object
#  2   price           float64
#  3   bed             float64
#  4   bath            float64
#  5   acre_lot        float64
#  6   street          float64
#  7   city            object
#  8   state           object
#  9   zip_code        float64
#  10  house_size      float64
#  11  prev_sold_date  object
# dtypes: float64(8), object(4)
# memory usage: 203.8+ MB

# %% [markdown]
# #COLUMN IS USED TO GET THE NAMES OF THE COLUMN

# %%
df.columns
# Out:
# Index(['brokered_by', 'status', 'price', 'bed', 'bath', 'acre_lot', 'street',
#        'city', 'state', 'zip_code', 'house_size', 'prev_sold_date'],
#       dtype='object')

# %% [markdown]
# #BASIC PLOTTING AND VISUAL BETWEEN DATASET

# %%
sns.pairplot(df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-1a6fe1782b2f> in <cell line: 1>()
# ----> 1 sns.pairplot(df)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2117     # Set up the PairGrid
#    2118     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 2119     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2120                     hue_order=hue_order, palette=palette, corner=corner,
#    2121                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#
# ...

# %% [markdown]
# #DISTRIBUTION OF PRICE

# %%
df['price'].plot.hist(bins=25,figsize=(8,4))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['house_size'].plot.hist(bins=25,figsize=(8,4))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['acre_lot'].plot.hist(bins=25,figsize=(8,4))
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# #CORRELATION MATRIX AND HEATMAP

# %%
for col in df.columns[:-1]:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
df.dropna(inplace=True)

# %%
df.corr()
# Out:
#                 brokered_by  status  price  bed  bath  acre_lot  street  city  \
# brokered_by             NaN     NaN    NaN  NaN   NaN       NaN     NaN   NaN
# status                  NaN     NaN    NaN  NaN   NaN       NaN     NaN   NaN
# price                   NaN     NaN    NaN  NaN   NaN       NaN     NaN   NaN
# bed                     NaN     NaN    NaN  NaN   NaN       NaN     NaN   NaN
# bath                    NaN     NaN    NaN  NaN   NaN       NaN     NaN   NaN
# acre_lot                NaN     NaN    NaN  NaN   NaN       NaN     NaN   NaN
# street                  NaN     NaN    NaN  NaN   NaN       NaN     NaN   NaN
# city                    NaN     NaN    NaN  NaN   NaN       NaN     NaN   NaN
# state                   NaN     NaN    NaN  NaN   NaN       NaN     NaN   NaN
# zip_code                NaN     NaN    NaN  NaN   NaN       NaN     NaN   NaN
# house_size              NaN     NaN    NaN  NaN   NaN       NaN     NaN   NaN
# ...

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(),annot=True,linewidth=2,cmap='coolwarm')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# <Axes: >
